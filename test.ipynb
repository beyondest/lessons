# %%
import numpy as np
import cv2
img=cv2.imread("res/mmm.png")
print(img.shape)
img=cv2.resize(img,(800,150),interpolation=cv2.INTER_LINEAR)
cv2.imshow("h",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite("mmm.png",img)
# Out:
# (731, 1115, 3)
# True

# %%
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
h,s,v=cv2.split(hsv)
imo.plt_show0(img)
imo.plt_show(h)
imo.plt_show(s)
imo.plt_show(v)

# %%
blue,green,red=cv2.split(img)
imo.plt_show0(img)
imo.plt_show(blue)
imo.plt_show(green)
imo.plt_show(red)
