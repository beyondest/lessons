# %%
import cv2
import numpy as np
import need
path3='D:/pycv/lessons/res/canny3.png'
path2='D:/pycv/lessons/res/sobel2.png'
img3=cv2.imread(path3)
img2=cv2.imread(path2)
img3_gray=cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
img2_gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret,thresh3=cv2.threshold(img3_gray,127,255,cv2.THRESH_BINARY)
ret,thresh2=cv2.threshold(img2_gray,127,255,cv2.THRESH_BINARY)
thr=thresh3[1023,1279]
print(thr)
need.plt_show(thresh3)
# Out:
# 0

# %%
med3=cv2.medianBlur(thresh3,5)
med2=cv2.medianBlur(thresh2,5)
need.plt_show(med3)
need.plt_show(med2)

# %%
#size of ker_rec is ()
ker_rec=cv2.getStructuringElement(cv2.MORPH_RECT,(10,10))
del_black3=cv2.morphologyEx(med3,cv2.MORPH_CLOSE,ker_rec,iterations=1)
del_black2=cv2.morphologyEx(med2,cv2.MORPH_CLOSE,ker_rec,iterations=1)
need.plt_show(del_black3)
need.plt_show(del_black2)

# %%
fuck=cv2.medianBlur(del_black3,5)
need.plt_show(fuck)

# %%
draw=img3.copy()
fuck_cons,fuck_arrs=cv2.findContours(fuck,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
a=need.get_4recpoints(fuck_cons[67])
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Before filter, remember to save the original conts so that you can use the original nums to find them
# 1:exclude rec_area smaller than 5000
# 2:exclude have sub_cont contour to find contour of picture '1'
# this could be done by child-parent contour match, color judge, width-height match ,area(real_cont)/area(rec_cont) to add points
# target:center point, wid, height, 4 corner points
# 3:calculate the ideal plate location:plate_loc
# 4:compare contours' locations together with recs' with plate_loc, access the grade of matched
# 5:try to define a func to autoly complete the uncompleted shape like 'C'
# 6:access the handmade contours grades
# 7:choose the highest grade one

# %%
ker_recx=cv2.getStructuringElement(cv2.MORPH_RECT,(50,1))
ker_recy=cv2.getStructuringElement(cv2.MORPH_RECT,(1,20))
close3=cv2.morphologyEx(del_black3,cv2.MORPH_CLOSE,ker_recx)
close2=cv2.morphologyEx(del_black2,cv2.MORPH_CLOSE,ker_recx)
plt_show(close3)
plt_show(close2)

# %%
del_white3=cv2.morphologyEx(close3,cv2.MORPH_OPEN,ker_recy,iterations=1)
del_white2=cv2.morphologyEx(close2,cv2.MORPH_OPEN,ker_recy,iterations=1)
plt_show(del_white3)
plt_show(del_white2)

# %%
#copy before you draw, or you will change the original_img
draw3=img3.copy()
draw2=img2.copy()

contours3,hierarchy3=cv2.findContours(thresh3,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
contours2,hierarchy2=cv2.findContours(thresh2,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)



#res2=cv2.drawContours(draw3,contours3,-1,(0,0,255),2)
#plt_show0(res3)
# Out:
# 297.0076904296875
